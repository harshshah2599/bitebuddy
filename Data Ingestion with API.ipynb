# %%
# !pip install google-search-results

from serpapi import GoogleSearch
# Out:
# Requirement already satisfied: google-search-results in /Users/harsh/anaconda3/lib/python3.11/site-packages (2.4.2)
# Requirement already satisfied: requests in /Users/harsh/anaconda3/lib/python3.11/site-packages (from google-search-results) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/harsh/anaconda3/lib/python3.11/site-packages (from requests->google-search-results) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/harsh/anaconda3/lib/python3.11/site-packages (from requests->google-search-results) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/harsh/anaconda3/lib/python3.11/site-packages (from requests->google-search-results) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/harsh/anaconda3/lib/python3.11/site-packages (from requests->google-search-results) (2023.7.22)

# %%
import pandas as pd

# Read the CSV file into a pandas DataFrame
data = pd.read_excel('Reviews_sample_data.xlsx')

#data.head()

# Extract the necessary columns
data = data[['GMAP_ID', 'BUSINESS_NAME']]

# Remove duplicates
data.drop_duplicates(subset=['GMAP_ID', 'BUSINESS_NAME'], keep='first', inplace=True)

data.head()
# Out:
#                                   GMAP_ID                   BUSINESS_NAME
# 0   0x89e379beb0d313f1:0x10b02efd0603f8c7     Rod D by Sitti Thai Cuisine
# 22  0x89e379b05bfd26f7:0x9f3c84bbb72e94a7  Dragon Star Chinese Restaurant
# 29  0x89e370867fa464fb:0x1bcdfafa076d7593                       Starbucks
# 37  0x89e37998feb8e86b:0x7c038659d4038815                  Dunkin' Donuts
# 38  0x89e379be79785077:0x9bf29e8bfa1f91fb             MIGAKU Noodle House

# %%
def get_gmap_id(selected_name):
    
    # Find the corresponding Gmap_id
    result = data[data['BUSINESS_NAME'] == selected_name]
    if not result.empty:
        return result['GMAP_ID'].values[0]
    else:
        return "No Gmap_id found for this restaurant name."

def get_reviews(restaurant_name):
    selected_name = restaurant_name
    gmap_id = get_gmap_id(selected_name)
    print(gmap_id)
    data_id = gmap_id

    params = {
      "api_key": "YOUR_SERPAPI_KEY",
      "engine": "google_maps_reviews",
      "hl": "en",
      "data_id": data_id
    }

    search = GoogleSearch(params)
    scapped_reviews = search.get_dict()
    return scapped_reviews

# %%
restaurant_name = "Dragon Star Chinese Restaurant"
raw_reviews_data = get_reviews(restaurant_name)
# Out:
# 0x89e379b05bfd26f7:0x9f3c84bbb72e94a7

# %%
raw_reviews_data
# Out:
# {'search_metadata': {'id': '6545c7214d443de2d22902d2',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/817bd655dee66788/6545c7214d443de2d22902d2.json',
#   'created_at': '2023-11-04 04:22:57 UTC',
#   'processed_at': '2023-11-04 04:22:57 UTC',
#   'google_maps_reviews_url': 'https://www.google.com/async/reviewDialog?hl=en&async=feature_id:0x89e379b05bfd26f7:0x9f3c84bbb72e94a7,sort_by:,next_page_token:,associated_topic:,_fmt:json',
#   'raw_html_file': 'https://serpapi.com/searches/817bd655dee66788/6545c7214d443de2d22902d2.html',
#   'prettify_html_file': 'https://serpapi.com/searches/817bd655dee66788/6545c7214d443de2d22902d2.prettify',
#   'total_time_taken': 1.37},
#  'search_parameters': {'engine': 'google_maps_reviews',
#   'data_id': '0x89e379b05bfd26f7:0x9f3c84bbb72e94a7',
#   'hl': 'en'},
#  'place_info': {'title': 'Dragon Star Chinese Restaurant',
#   'address': '700 Washington St, Brookline, MA',
#   'rating': 4.2,
#   'reviews': 142},
#  'topics': [{'keyword': 'price', 'mentions': 25, 'id': '/m/01d_1l'},
#   {'keyword': 'american chinese food', 'mentions': 9, 'id': '/m/0qxx'},
#   {'keyword': 'delivery', 'mentions': 7, 'id': '/m/035bpb'},
#   {'keyword': 'quantities', 'mentions': 6, 'id': '/m/0334cs'},
#   {'keyword': 'crab rangoons', 'mentions': 5, 'id': '/m/064b8z'},
#   {'keyword': 'spare ribs', 'mentions': 4, 'id': '/m/0g4q3r'},
#   {'keyword': 'cash', 'mentions': 3, 'id': '/m/0fd6q'},
#   {'keyword': 'order', 'mentions': 3, 'id': '/m/01qbmz'},
#   {'keyword': 'teriyaki', 'mentions': 3, 'id': '/m/018gxk'},
#   {'keyword': 'cook', 'mentions': 3, 'id': '/m/04y7pl'}],
#  'reviews': [{'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSUN1a29uYTF3RRAB!2m1!1s0x0:0x9f3c84bbb72e94a7!3m1!1s2@1:CIHM0ogKEICAgICukona1wE%7CCgsI-7P2lgYQ0KqlRA%7C?hl=en-US',
#    'rating': 3.0,
#    'date': 'a year ago',
#    'images': ['https://lh5.googleusercontent.com/p/AF1QipNXBjJaSPZFEOkN7BSa9lnuy6n3RMQlgzJGgSPH=w100-h100-p-n-k-no',
#     'https://lh5.googleusercontent.com/p/AF1QipP0DKcqXzO24pQvZ870f-CBfxlaNbqToumdPz_F=w100-h100-p-n-k-no',
#     'https://lh5.googleusercontent.com/p/AF1QipMsk_cI6y8QUWNvFEPztXqDKZBRJS8CvKWL45t6=w100-h100-p-n-k-no',
#     'https://lh5.googleusercontent.com/p/AF1QipNXKNyrQ1E-ne-DAFXHHpbm6c3Iojj7wbnZfSCl=w100-h100-p-n-k-no'],
#    'source': 'Google',
#    'review_id': 'ChdDSUhNMG9nS0VJQ0FnSUN1a29uYTF3RRAB',
#    'user': {'name': 'mathieu baissac',
#     'link': 'https://www.google.com/maps/contrib/109987009138538811553?hl=en-US',
#     'contributor_id': '109987009138538811553',
#     'thumbnail': 'https://lh3.googleusercontent.com/a/ACg8ocKmACOyXYD0JuuE__gf6FfG_clyO-WuCzhukQpGweq3=s40-c-rp-mo-ba4-br100',
#     'local_guide': True,
#     'reviews': 94,
#     'photos': 305},
#    'snippet': 'Expected American-chinese food. The large size is huge- could easily share 2 large with 3 people. The food is goopey and unsubtle. Take out was ready in 10 minutes! Fast, cheap and basic fare.',
#    'extensions': ['Take out', 'Dinner', '$20–30'],
#    'details': {'mode': 'Take out',
#     'meal_type': 'Dinner',
#     'price_range': '$20–30'}},
#   {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSUR4bW83aHVRRRAB!2m1!1s0x0:0x9f3c84bbb72e94a7!3m1!1s2@1:CIHM0ogKEICAgIDxmo7huQE%7CCgwIhpn8owYQ4LDQjgI%7C?hl=en-US',
#    'rating': 5.0,
#    'date': '4 months ago',
#    'images': ['https://lh5.googleusercontent.com/p/AF1QipMyhmfEzxSczATMxu4HMVCowFmWakSCi6kOe6z5=w100-h100-p-n-k-no'],
#    'source': 'Google',
#    'review_id': 'ChdDSUhNMG9nS0VJQ0FnSUR4bW83aHVRRRAB',
#    'user': {'name': 'Richard Damanik',
#     'link': 'https://www.google.com/maps/contrib/112077345905940722368?hl=en-US',
#     'contributor_id': '112077345905940722368',
#     'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjXw8ZpINUaFAXz15mRcPu92e--tU-EWtJ2dh-jEqgWoAEox=s40-c-rp-mo-br100',
#     'reviews': 7,
#     'photos': 7},
#    'snippet': 'Suprised with the taste..\nUnlike the usual american chinese cuisine, it tastes better than others.\nYou have to bring cash if your food under 15 dollars',
#    'extensions': ['Take out', 'Dinner', '$10–20'],
#    'details': {'mode': 'Take out',
#     'meal_type': 'Dinner',
#     'price_range': '$10–20',
#     'recommended_dishes': 'Roasted Pork Fried Rice, Chicken Fingers'}},
#   {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSURtbTRPN1N3EAE!2m1!1s0x0:0x9f3c84bbb72e94a7!3m1!1s2@1:CIHM0ogKEICAgIDmm4O7Sw%7CCgwI2aqSkAYQ-O38yAM%7C?hl=en-US',
#    'rating': 5.0,
#    'date': 'a year ago',
#    'images': ['https://lh5.googleusercontent.com/p/AF1QipM6irCVTuwBPPstoVCuKaxGZO3JEqbT4XHa99MW=w100-h100-p-n-k-no',
#     'https://lh5.googleusercontent.com/p/AF1QipOE0z2GRU3mb1TgxB0-dg7gK-KAyb8l8HbA3Q9M=w100-h100-p-n-k-no'],
#    'source': 'Google',
#    'review_id': 'ChZDSUhNMG9nS0VJQ0FnSURtbTRPN1N3EAE',
#    'user': {'name': 'Rajesh Prabhu',
#     'link': 'https://www.google.com/maps/contrib/109267107548591972973?hl=en-US',
#     'contributor_id': '109267107548591972973',
#     'thumbnail': 'https://lh3.googleusercontent.com/a/ACg8ocKWhXSIHF6XrG8iUHxQSwoEToyUTltbMeqA33AlhIKX=s40-c-rp-mo-ba5-br100',
#     'local_guide': True,
#     'reviews': 128,
#     'photos': 633},
#    'snippet': "We always try the lo mein noodles and they offer buy one and get one half price for most of their meals. The food is always tasty and good. Compared to other restaurants, they are very inexpensive and great quality and quantity for that price. We have been going to this place for almost a year now and still we don't get tired. Nice place and great customer service, food is ready within minutes. Worth a try.",
#    'likes': 1},
#   {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSUN4Z01HS1hBEAE!2m1!1s0x0:0x9f3c84bbb72e94a7!3m1!1s2@1:CIHM0ogKEICAgICxgMGKXA%7CCgwIg73gogYQoJ3qxgI%7C?hl=en-US',
#    'rating': 5.0,
#    'date': '5 months ago',
#    'images': ['https://lh5.googleusercontent.com/p/AF1QipPTdcWaxCR-BWVXSV229KJgDugHxgzkvAqxLth4=w100-h100-p-n-k-no'],
#    'source': 'Google',
#    'review_id': 'ChZDSUhNMG9nS0VJQ0FnSUN4Z01HS1hBEAE',
#    'user': {'name': 'Molly Turner',
#     'link': 'https://www.google.com/maps/contrib/107569937774699270180?hl=en-US',
#     'contributor_id': '107569937774699270180',
#     'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjW44Juv79ZPSJlvfGpoPg-Wu0jtBTHUP01XhVj6WltGIOst=s40-c-rp-mo-br100',
#     'reviews': 16,
#     'photos': 9},
#    'snippet': 'delicious and fast. cash only for charges under $15. small portion is plenty for me.',
#    'extensions': ['Take out'],
#    'details': {'mode': 'Take out'},
#    'likes': 1},
#   {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSUR4emQyWlBREAE!2m1!1s0x0:0x9f3c84bbb72e94a7!3m1!1s2@1:CIHM0ogKEICAgIDxzd2ZPQ%7CCgwIm5yhpAYQqLbjuQM%7C?hl=en-US',
#    'rating': 4.0,
#    'date': '4 months ago',
#    'source': 'Google',
#    'review_id': 'ChZDSUhNMG9nS0VJQ0FnSUR4emQyWlBREAE',
#    'user': {'name': 'idle harps',
#     'link': 'https://www.google.com/maps/contrib/117738187504427549841?hl=en-US',
#     'contributor_id': '117738187504427549841',
#     'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjUA8fkmPC9b1G5RkFhxobtdVOqezwm_UWhk6ODC8v7Hmqg=s40-c-rp-mo-br100',
#     'reviews': 7,
#     'photos': 6},
#    'snippet': 'the food is pretty good and pretty cheep with the buy one get the same thing half off. i got dumpings, crab rangoons and pork fried rice. the rice was eh but the other two were excellent.',
#    'details': {'food': '3/5', 'service': '5/5', 'atmosphere': '4/5'}},
#   {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSUNKcXRMOVpBEAE!2m1!1s0x0:0x9f3c84bbb72e94a7!3m1!1s2@1:CIHM0ogKEICAgICJqtL9ZA%7CCgsItpvepAYQ0OHgRg%7C?hl=en-US',
#    'rating': 5.0,
#    'date': '4 months ago',
#    'source': 'Google',
#    'review_id': 'ChZDSUhNMG9nS0VJQ0FnSUNKcXRMOVpBEAE',
#    'user': {'name': 'Joshua Vicente',
#     'link': 'https://www.google.com/maps/contrib/114874695555773386505?hl=en-US',
#     'contributor_id': '114874695555773386505',
#     'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjVJJyvUQM_o-24Oc3YG-wTbh3oSXBn39KmNWzw-n5HM0NI=s40-c-rp-mo-ba4-br100',
#     'local_guide': True,
#     'reviews': 128,
#     'photos': 25},
#    'snippet': "Great food and services not much seating but it's perfect for takeout lunch specials or dinner",
#    'extensions': ['Dine in', 'Lunch', '$10–20'],
#    'details': {'mode': 'Dine in',
#     'meal_type': 'Lunch',
#     'price_range': '$10–20',
#     'food': '5/5',
#     'service': '5/5',
#     'atmosphere': '4/5'}},
#   {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSURCMHZETHVnRRAB!2m1!1s0x0:0x9f3c84bbb72e94a7!3m1!1s2@1:CIHM0ogKEICAgIDB0vDLugE%7CCgwIi-KQngYQ-LGLpwE%7C?hl=en-US',
#    'rating': 2.0,
#    'date': '9 months ago',
#    'source': 'Google',
#    'review_id': 'ChdDSUhNMG9nS0VJQ0FnSURCMHZETHVnRRAB',
#    'user': {'name': 'cat',
#     'link': 'https://www.google.com/maps/contrib/102153251354225348312?hl=en-US',
#     'contributor_id': '102153251354225348312',
#     'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjX6OUEPPBnUsqHYmJY8or29mlcGZZLj2KEcp6GZ86svfw=s40-c-rp-mo-ba6-br100',
#     'local_guide': True,
#     'reviews': 946,
#     'photos': 64},
#    'snippet': 'Most of the items have weird tastes, their sauces tasted funny regardless from the perspectives of being American Chinese or traditional Chinese food. Poor quality and quantities. There are many more better Chinese takeout places to go.',
#    'likes': 2},
#   {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSUQtN09hdFVBEAE!2m1!1s0x0:0x9f3c84bbb72e94a7!3m1!1s2@1:CIHM0ogKEICAgID-7OatUA%7CCgwI4M_4mwYQ6J3dmwM%7C?hl=en-US',
#    'rating': 5.0,
#    'date': '11 months ago',
#    'source': 'Google',
#    'review_id': 'ChZDSUhNMG9nS0VJQ0FnSUQtN09hdFVBEAE',
#    'user': {'name': 'M M',
#     'link': 'https://www.google.com/maps/contrib/107488034573486986116?hl=en-US',
#     'contributor_id': '107488034573486986116',
#     'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjW0-8bdVn1bTQhyzxUutJs3cp20HuO4VfDbDoorMyvpV68=s40-c-rp-mo-ba3-br100',
#     'local_guide': True,
#     'reviews': 19,
#     'photos': 8},
#    'snippet': '11/22/22:\n\nI stopped here after an appointment in the area, first time here, so I didn’t know what to expect.\n\nSTAFF: Gentlemen at the counter didn’t mind answering my questions or altering my food order, he was very nice and no attitude, It’s an open kitchen: you can see the chefs do everything while you wait\n\nFOOD: Crab Rangoon, Boneless Spareribs, White Shrimp Fried Rice, Chicken Teriyaki, and Spring Roll: No complaints on anything. Everything was demolished.   \n\nPRICE: MANY OF THE APPS/ENTREES HAVE BOGO OPTIONS, WORTH TAKING ADVANTAGE OF.\n\nI LIKE THIS PLACE. MAYBE YOU WILL TOO.',
#    'extensions': ['Take out', 'Dinner', '$10–20'],
#    'details': {'staff': 'Gentlemen at the counter didn’t mind answering my questions or altering my food order, he was very nice and no attitude, It’s an open kitchen you can see the chefs do everything while you wait',
#     'food': 'Crab Rangoon, Boneless Spareribs, White Shrimp Fried Rice, Chicken Teriyaki, and Spring Roll No complaints on anything. Everything was demolished.',
#     'price': 'MANY OF THE APPS/ENTREES HAVE BOGO OPTIONS, WORTH TAKING ADVANTAGE OF.',
#     'mode': 'Take out',
#     'meal_type': 'Dinner',
#     'price_range': '$10–20'},
#    'likes': 1},
#   {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSUNHNU15eF9nRRAB!2m1!1s0x0:0x9f3c84bbb72e94a7!3m1!1s2@1:CIHM0ogKEICAgICG5Myx_gE%7CCgwIyb7CiwYQ4M-O5gI%7C?hl=en-US',
#    'rating': 4.0,
#    'date': '2 years ago',
#    'source': 'Google',
#    'review_id': 'ChdDSUhNMG9nS0VJQ0FnSUNHNU15eF9nRRAB',
#    'user': {'name': 'Daisy Mendez',
#     'link': 'https://www.google.com/maps/contrib/111538491115292468161?hl=en-US',
#     'contributor_id': '111538491115292468161',
#     'thumbnail': 'https://lh3.googleusercontent.com/a/ACg8ocJWLQZcz1wa4fQDqoHLNlxOVfouvenBRDNvKme7_epTTg=s40-c-rp-mo-ba3-br100',
#     'local_guide': True,
#     'reviews': 42,
#     'photos': 18},
#    'snippet': 'This location has really really good Chinese food. However  the owner tried to tell me the card minimum is 15 $ and that is a lie. I work for a bank and know that there is no such minimum on credit and debt card machines to charge in stores. That is at the owners discretion but they clearly prefer cash and had a ridiculous minimum of 15 for your card where most places its $10. The meal was around $11.\n\nOther than that I got a lunch special beef and broccoli and so much food on the plate so I appreciated that and it taste fresh.',
#    'extensions': ['Take out', 'Lunch', '$10–20'],
#    'details': {'mode': 'Take out',
#     'meal_type': 'Lunch',
#     'price_range': '$10–20'},
#    'likes': 3},
#   {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSURVNC0teVpnEAE!2m1!1s0x0:0x9f3c84bbb72e94a7!3m1!1s2@1:CIHM0ogKEICAgIDU4--yZg%7CCgwI94G36wUQgNOxmwE%7C?hl=en-US',
#    'rating': 2.0,
#    'date': '4 years ago',
#    'source': 'Google',
#    'review_id': 'ChZDSUhNMG9nS0VJQ0FnSURVNC0teVpnEAE',
#    'user': {'name': 'Brandon Bellanti',
#     'link': 'https://www.google.com/maps/contrib/116268474196009854062?hl=en-US',
#     'contributor_id': '116268474196009854062',
#     'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjXCOffID2xA3NLfoJLd8kNQgDK-ihTWGV3YuFTGOpByxu0O=s40-c-rp-mo-ba3-br100',
#     'local_guide': True,
#     'reviews': 54},
#    'snippet': "We typically have good experiences at Dragon Star, but we tried to get our order delivered tonight, and it was a disaster. I ordered over the phone and was told it would be an hour to get the food (a long time, but understandable because it's Labor Day and I'm sure they are busy).\n\nAfter an hour and twenty minutes, I called to ask about our order, and they said it would be there soon. After another fifteen minutes and no contact from the driver, we called again to ask where the food was. They said they could not reach us because we had given them the wrong phone number, but they read it back to us and the phone number was correct. We asked why they didn't ring the doorbell because they had our apartment number, and we were home the entire time. They just responded that they had called several times and it was our fault for not picking up (again, we verified that we had given the correct number and did not receive any calls).\n\nFinally, we ended up just walking down to the restaurant to pick up the food because the driver had brought it back. I asked for a discount because the food was 45 minutes late by the time we got there, and we had not been contacted a single time. They refused to give any discount because I had already paid over the phone.\n\nAgain, the food here is generally good, but after this experience, it will be a while before I order from them again, and I will never do delivery from them.",
#    'likes': 1}],
#  'serpapi_pagination': {'next': 'https://serpapi.com/search.json?data_id=0x89e379b05bfd26f7%3A0x9f3c84bbb72e94a7&engine=google_maps_reviews&hl=en&next_page_token=CAESBkVnSUlDZw%3D%3D',
#   'next_page_token': 'CAESBkVnSUlDZw=='}}

# %%
# !pip install pandas

import pandas as pd
# Out:
# Requirement already satisfied: pandas in /Users/harsh/anaconda3/lib/python3.11/site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/harsh/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/harsh/anaconda3/lib/python3.11/site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /Users/harsh/anaconda3/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /Users/harsh/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
# # Extract the restaurant name and snippets
# restaurant_name = raw_reviews_data['place_info']['title']
# comments = [review['snippet'] for review in raw_reviews_data['reviews']]

# # Create a DataFrame
# df = pd.DataFrame({'Restaurant Name': [restaurant_name] * len(comments), 'Reviews': comments})

# # Display the DataFrame
# df.head()

# Extract the restaurant name and snippets
restaurant_name = raw_reviews_data['place_info']['title']
snippets = ' '.join([review['snippet'] for review in raw_reviews_data['reviews']])
recommended_dishes = ''.join([review.get('details', {}).get('recommended_dishes', '') for review in raw_reviews_data['reviews']])
print("Recommended Dishes:\n",recommended_dishes)
print("\n\n")
print("Comments:\n",snippets)
# Create a DataFrame
df = pd.DataFrame({'Restaurant Name': [restaurant_name], 'Reviews': [snippets], 'Recommended Dishes':[recommended_dishes]})
# Out:
# Recommended Dishes:
#  Roasted Pork Fried Rice, Chicken Fingers
#
#
#
# Comments:
#  Expected American-chinese food. The large size is huge- could easily share 2 large with 3 people. The food is goopey and unsubtle. Take out was ready in 10 minutes! Fast, cheap and basic fare. Suprised with the taste..
# Unlike the usual american chinese cuisine, it tastes better than others.
# You have to bring cash if your food under 15 dollars We always try the lo mein noodles and they offer buy one and get one half price for most of their meals. The food is always tasty and good. Compared to other restaurants, they are very inexpensive and great quality and quantity for that price. We have been going to this place for almost a year now and still we don't get tired. Nice place and great customer service, food is ready within minutes. Worth a try. delicious and fast. cash only for charges under $15. small portion is plenty for me. the food is pretty good and pretty cheep with the buy one get the same thing half off. i got dumpings, crab rangoons and pork fried rice. the rice was eh but the other two were excellent. Great food and services not much seating but it's perfect for takeout lunch specials or dinner Most of the items have weird tastes, their sauces tasted funny regardless from the perspectives of being American Chinese or traditional Chinese food. Poor quality and quantities. There are many more better Chinese takeout places to go. 11/22/22:
#
# I stopped here after an appointment in the area, first time here, so I didn’t know what to expect.
#
# STAFF: Gentlemen at the counter didn’t mind answering my questions or altering my food order, he was very nice and no attitude, It’s an open kitchen: you can see the chefs do everything while you wait
#
# FOOD: Crab Rangoon, Boneless Spareribs, White Shrimp Fried Rice, Chicken Teriyaki, and Spring Roll: No complaints on anything. Everything was demolished.
#
# PRICE: MANY OF THE APPS/ENTREES HAVE BOGO OPTIONS, WORTH TAKING ADVANTAGE OF.
#
# I LIKE THIS PLACE. MAYBE YOU WILL TOO. This location has really really good Chinese food. However  the owner tried to tell me the card minimum is 15 $ and that is a lie. I work for a bank and know that there is no such minimum on credit and debt card machines to charge in stores. That is at the owners discretion but they clearly prefer cash and had a ridiculous minimum of 15 for your card where most places its $10. The meal was around $11.
#
# Other than that I got a lunch special beef and broccoli and so much food on the plate so I appreciated that and it taste fresh. We typically have good experiences at Dragon Star, but we tried to get our order delivered tonight, and it was a disaster. I ordered over the phone and was told it would be an hour to get the food (a long time, but understandable because it's Labor Day and I'm sure they are busy).
#
# After an hour and twenty minutes, I called to ask about our order, and they said it would be there soon. After another fifteen minutes and no contact from the driver, we called again to ask where the food was. They said they could not reach us because we had given them the wrong phone number, but they read it back to us and the phone number was correct. We asked why they didn't ring the doorbell because they had our apartment number, and we were home the entire time. They just responded that they had called several times and it was our fault for not picking up (again, we verified that we had given the correct number and did not receive any calls).
#
# Finally, we ended up just walking down to the restaurant to pick up the food because the driver had brought it back. I asked for a discount because the food was 45 minutes late by the time we got there, and we had not been contacted a single time. They refused to give any discount because I had already paid over the phone.
#
# Again, the food here is generally good, but after this experience, it will be a while before I order from them again, and I will never do delivery from them.

# %%
# Display the DataFrame
df.head()
# Out:
#                   Restaurant Name  \
# 0  Dragon Star Chinese Restaurant
#
#                                              Reviews  \
# 0  Expected American-chinese food. The large size...
#
#                          Recommended Dishes
# 0  Roasted Pork Fried Rice, Chicken Fingers
